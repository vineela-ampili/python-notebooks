# %% [markdown]
# <a href="https://colab.research.google.com/github/vineela-ampili/python-notebooks/blob/main/notebooks/algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):

    return sorted(word1.lower())==sorted(word2.lower())

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# True

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies

# %%
is_anagram('top', 'post') # False, letters left over at the end

# %%
is_anagram('topss', 'postt') # False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 815 ns ± 56 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 1.5 µs ± 317 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
def all_anagram_pairs(word_list):
  for word1 in word_list:
    for word2 in word_list:
      if is_anagram(word1,word2):
        print(word1,word2)

# %%
all_anagram_pairs(short_word_list)
# Out:
# proudest proudest
# proudest sprouted
# stop stop
# stop pots
# stop tops
# pots stop
# pots pots
# pots tops
# tops stop
# tops pots
# tops tops
# sprouted proudest
# sprouted sprouted

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)

download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %%
def all_anagram_pairs(word_list):
  for word1 in word_list:
    if is_anagram(word1,'stop'):
      print(word1)

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
pairs = all_anagram_pairs(word_list)
# Out:
# spot
# opts
# pots
# stop
# tops
# post

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %%
# %time all_anagram_pairs(word_list)
# Out:
# spot
# opts
# pots
# stop
# tops
# post
# CPU times: user 153 ms, sys: 0 ns, total: 153 ms
# Wall time: 152 ms

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_lists(word_list):
    """Finds all anagrams in a list of words.

    word_list: sequence of strings
    """

    anagram_map = {}
    for word in word_list:
        signature = ''.join(sorted(word))
        if signature not in anagram_map:
            anagram_map[signature] = [word]
        else:
            anagram_map[signature].append(word)
    return anagram_map

# %%
anagram_map = all_anagram_lists(word_list)
print(anagram_map)
# Out:
# {'agnors': ['organs', 'sargon', 'groans', 'sarong'], 'aaaccinssu': ['caucasians'], 'aabcceeirrsuu': ['bureaucracies'], "'eesttv": ["tevet's"], 'ceinosst': ['sections'], 'aeiknsstw': ['swankiest'], 'eimrssst': ['mistress'], "'ilsvy": ["livy's"], 'chpssy': ['psychs'], 'addeehrsty': ['dehydrates'], 'abceorrrtu': ['carburetor'], "'acdmnorsy": ["dormancy's"], "'aeghopprrsss": ["grasshopper's"], 'ceefinorr': ['reinforce'], 'aelnps': ['planes', 'panels', 'naples'], 'abeenntu': ['unbeaten'], 'deeikllr': ['killdeer'], 'opsttuu': ['outputs'], 'eiimoprsuv': ['impervious'], 'abnoosss': ['bassoons'], "'abciinrss": ["scriabin's"], 'acehinoprrss': ['chairpersons'], "'bilnoss": ["lisbon's"], 'achkl': ['chalk'], 'cceilst': ['celtics'], "'aiknrssstvy": ["stravinsky's"], 'bcehiisssu': ['hibiscuses'], "'eilnoorsstu": ["resolution's"], 'aacilott': ['tailcoat'], 'aceeklmr': ['mackerel'], 'beinrtu': ['tribune', 'turbine'], 'eeegikr': ['geekier'], 'arty': ['tray', 'arty'], "'acmnossst": ["scotsman's"], 'aabeelprty': ['repeatably'], 'ainrs': ['rains'], 'amx': ['max'], "'aceeilnnorst": ["intolerance's"], 'efiirrtu': ['fruitier'], 'aeiloppsty': ['appositely'], "'gostu": ["gout's"], 'dglmossu': ['slumdogs'], 'dinrs': ['rinds'], 'oprtô': ['pôrto'], 'ailrwy': ['warily'], 'aacekrtt': ['attacker'], 'floos': ['fools'], "'eimrssy": ["misery's"], "'emrsstyy": ["mystery's"], 'cdeiloprtuvy': ['productively'], 'eeefgru': ['refugee'], 'aehnnrstuä': ['tannhäuser'], 'eekmoorv': ['kemerovo'], "'delpsux": ["duplex's"], 'hrttu': ['truth'], 'adeghrtuy': ['daugherty'], "'aiilnqrsttuy": ["tranquility's"], 'cdeellnrsu': ['cullenders'], 'cdeelw': ['clewed'], 'psst': ['psst'], 'acgiinprst': ['practising'], 'aacenr': ['arcane'], 'aaccefprst': ['spacecraft'], "'aeghimnorssuw": ["housewarming's"], "'aehlsw": ["whale's", "wheal's"], 'ceesux': ['excuse'], "'aaaclpst": ["catalpa's"], 'ccefiirsux': ['crucifixes'], 'eeffgn': ['geffen'], 'aeefmnor': ['forename'], 'instt': ['tints', 'stint'], "'aeipsssv": ["passive's"], "'aekqsu": ["quake's"], 'acdensu': ['uncased'], 'dfinrssuw': ['windsurfs'], 'beggilnno': ['belonging'], 'deef': ['feed'], 'aghopprtyy': ['typography'], 'addeeimmnrst': ['masterminded'], "'emrst": ["term's"], 'aefgilnrt': ['faltering'], 'acdeemprs': ['scampered'], "'ceenrss": ["screen's", "censer's"], 'eepstt': ['septet'], "'adhinoosst": ["sainthood's"], 'aceelnrvy': ['relevancy'], 'glloy': ['golly'], 'gilnos': ['losing', 'lingos', 'soling', 'logins'], 'eegoprssu': ['superegos'], 'aablny': ['albany'], 'ceiinrtyz': ['citizenry'], 'eginppp': ['pepping'], 'acellrs': ['callers', 'cellars', 'recalls'], 'aainqrtu': ['quatrain'], 'ailort': ['tailor'], 'osst': ['toss', 'sots'], 'gginopr': ['groping'], 'aaitw': ['await'], 'aginorrs': ['garrison'], 'ginpppu': ['pupping'], 'noy': ['yon'], 'aeemnrsuv': ['maneuvers'], "'abiinors": ["nairobi's"], 'bbefirs': ['fibbers'], "'emosss": ["moses's"], "'ahlss": ["hals's", "lash's"], 'acmps': ['scamp', 'camps'], 'abcelln': ['leblanc'], "'acehsvz": ["chavez's"], 'abdeilp': ['bipedal', 'piebald'], 'bgnsu': ['bungs'], 'aimorrtt': ['marriott'], 'cdeennost': ['consented'], 'agillnru': ['alluring'], "'aeilmnoprst": ["trampoline's"], "'aaeghilrsst": ["rasalgethi's"], "'eipprrsst": ["stripper's"], "'ccceiimnoprsstu": ["circumspection's"], "'aciinnoopsstt": ["constipation's"], 'aadllnp': ['lapland'], "'acehlnns": ["channel's"], 'eeefnqrrtu': ['frequenter'], "'iprrsstu": ["stirrup's"], 'aaceghilllmpty': ['phlegmatically'], "'abbdgginnors": ["brobdingnag's"], 'eeelnsv': ['elevens'], 'agnprs': ['sprang'], "'ceekrstu": ["truckee's"], 'aabdnrrsy': ['barnyards'], 'emnort': ['mentor', 'merton'], 'benoy': ['boney', 'ebony'], "'bdeoorrs": ["brooder's"], "'cdehloopprs": ["clodhopper's"], 'ilot': ['toil'], 'aaeeilrstt': ['retaliates'], 'acelmstu': ['muscatel'], "'accdiiirst": ["diacritic's"], 'ehlost': ['hostel', 'helots', 'lhotse', 'hotels'], 'ekknstuz': ['kuznetsk'], 'fiiilnops': ['filipinos'], 'bddenou': ['bounded'], "'ghiilnooorsstt": ["ornithologist's"], "'a ...

# %%
# %time anagram_map = all_anagram_lists(word_list)
# Out:
# CPU times: user 364 ms, sys: 4.94 ms, total: 369 ms
# Wall time: 369 ms

# %%
len(anagram_map)
# Out:
# 93406

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
anagram_map = all_anagram_lists(word_list)

more_than_one = {k:v for k,v in anagram_map.items() if len(v)>1}
more_than_one
# Out:
# {'agnors': ['organs', 'sargon', 'groans', 'sarong'],
#  'aelnps': ['planes', 'panels', 'naples'],
#  'beinrtu': ['tribune', 'turbine'],
#  'arty': ['tray', 'arty'],
#  "'aehlsw": ["whale's", "wheal's"],
#  'instt': ['tints', 'stint'],
#  "'ceenrss": ["screen's", "censer's"],
#  'gilnos': ['losing', 'lingos', 'soling', 'logins'],
#  'acellrs': ['callers', 'cellars', 'recalls'],
#  'osst': ['toss', 'sots'],
#  "'ahlss": ["hals's", "lash's"],
#  'acmps': ['scamp', 'camps'],
#  'abdeilp': ['bipedal', 'piebald'],
#  'emnort': ['mentor', 'merton'],
#  'benoy': ['boney', 'ebony'],
#  'ehlost': ['hostel', 'helots', 'lhotse', 'hotels'],
#  'aflo': ['foal', 'olaf', 'loaf'],
#  'eelmr': ['merle', 'elmer'],
#  'deor': ['oder', 'rode', 'redo', 'doer'],
#  'eerstt': ['tester', 'setter', 'street'],
#  "'bcesu": ["cube's", "cebu's"],
#  "'eersstt": ["setter's", "street's", "tester's"],
#  'aadeiprst': ['aspirated', 'disparate'],
#  'ex': ['ex', 'xe'],
#  'adehps': ['shaped', 'phased'],
#  'eeelprss': ['sleepers', 'peerless'],
#  'eginstt': ['setting', 'testing'],
#  'aemst': ['tames', 'meats', 'mates', 'steam', 'teams'],
#  "'egorrs": ["roger's", "regor's", "reorg's"],
#  "'acdemors": ["mercado's", "comrade's"],
#  'deeerv': ['reeved', 'veered'],
#  'aellorv': ['allover', 'overall'],
#  'bstu': ['buts', 'bust', 'tubs', 'stub'],
#  'abls': ['slab', 'albs', 'labs'],
#  'deorst': ['dorset', 'sorted', 'strode', 'stored'],
#  "'aesstw": ["waste's", "sweat's"],
#  'aegilns': ['sealing', 'leasing'],
#  'eint': ['nite', 'tine'],
#  "'eeilmnosst": ["limestone's", "milestone's"],
#  'ikst': ['skit', 'kits'],
#  'eiknrst': ['tinkers', 'kirsten', 'stinker', 'kristen'],
#  "'aalrs": ["lara's", "aral's", "alar's"],
#  'eikln': ['liken', 'klein', 'kline'],
#  'eno': ['eon', 'neo', 'one', 'noe'],
#  'aeeegnrst': ['generates', 'teenagers'],
#  'behirrst': ['rebirths', 'birthers'],
#  'cejnosu': ['jounces', 'juncoes'],
#  'eoprrst': ['porters', 'reports'],
#  'eelnor': ['lorene', 'lenore'],
#  'dot': ['dot', 'tod'],
#  'aefkrs': ['freaks', 'fakers'],
#  'beest': ['beset', 'beets'],
#  'cdeenors': ['encoders', 'censored'],
#  'aeoprssv': ['passover', 'overpass'],
#  'defgit': ['gifted', 'fidget'],
#  'aden': ['dean', 'dena', 'edna', 'aden', 'dane'],
#  'aerstu': ['atreus', 'seurat'],
#  "'abdnrsu": ["durban's", "dunbar's"],
#  'aabdeginr': ['gabardine', 'bargained'],
#  'adil': ['laid', 'dial', 'dali'],
#  'aell': ['ella', 'lela'],
#  'aelpsst': ['pastels', 'staples'],
#  'einprrst': ['sprinter', 'reprints', 'printers'],
#  'beghinrt': ['brighten', 'berthing'],
#  "'alostuy": ["outlay's", "layout's"],
#  "'abdrs": ["bard's", "drab's", "brad's"],
#  "'aenps": ["pena's", "nape's", "pane's"],
#  'orsu': ['sour', 'ours'],
#  'aors': ['soar', 'oars', 'rosa'],
#  "'eorssty": ["oyster's", "storey's"],
#  'ahmnnstu': ['manhunts', 'huntsman'],
#  "''bnoss": ["bos'n's", "bo's'ns"],
#  'adegilnp': ['pleading', 'pedaling'],
#  'amnoor': ['maroon', 'romano'],
#  'acersst': ['recasts', 'actress', 'casters'],
#  'aor': ['ora', 'oar'],
#  'aflos': ['loafs', 'foals'],
#  'egls': ['legs', 'gels'],
#  'aeerrstu': ['treasure', 'austerer'],
#  'bcklnosu': ['unblocks', 'sunblock'],
#  'aeprss': ['parses', 'passer', 'spears', 'sparse', 'spares'],
#  'egginorr': ['reorging', 'rogering'],
#  'ittw': ['twit', 'witt'],
#  'aceinsstt': ['tacitness', 'cattiness', 'scantiest'],
#  'deisv': ['dives', 'vised'],
#  'deeorrst': ['restored', 'resorted'],
#  "'apsst": ["spat's", "past's"],
#  'bmoos': ['bosom', 'booms'],
#  "'acnorsy": ["crayon's", "cyrano's"],
#  'ehirtw': ['writhe', 'whiter', 'wither'],
#  "'giinrsv": ["virgin's", "irving's"],
#  'eflu': ['fuel', 'flue'],
#  'deoprstu': ['postured', 'proudest', 'sprouted'],
#  'aegnrrs': ['rangers', 'garners'],
#  'accgikln': ['cackling', 'clacking'],
#  "'cinos": ["icon's", "coin's"],
#  'biilntu': ['inbuilt', 'builtin'],
#  'enrst': ['rents', 'terns', 'ernst', 'stern'],
#  'aghilmorst': ['logarithms', 'algorithms'],
#  'aabdimr': ['mariadb', 'barmaid'],
#  "'amorsy": ["moray's", "mayor's"],
#  'eopssu': ['spouse', 'opuses'],
#  'adeelry': ['relayed', 'layered'],
#  'acehmrr': ['charmer', 'marcher'],
#  'efflrtu': ['truffle', 'fretful'],
#  'eeeprrsv': ['preserve', 'perverse'],
#  "'aeemnssst": ["tameness's", "massenet's"],
#  "'aeps": ["ape's", "pea's"],
#  'adelor': ['laredo', 'loader', 'ordeal', 'reload'],
#  'deelorw': ['lowered', 'roweled'],
#  'bdeeils': ['edibles', 'delibes'],
#  'deilss': ['slides', 'sidles'],
#  'abeillry': ['reliably', 'blearily'],
#  'aceinnsst': ['instances', 'incessant'],
#  'ags': ['sag', 'gas'],
#  'dim': ['mid', 'dim'],
#  'degilnt': ['tingled', 'glinted'],
#  'gimnpsu': ['impugns', 'spuming'],
#  'aeelss': ['leases', 'easels'],
#  "'aceehrrss": ["research's", "searcher's"],
#  'aceirsst': ['scariest', 'castries'],
#  'denst': ['dents', 'tends'],
#  'below': ['elbow', 'bowel', 'below'],
#  'abdeorr': ['broader', 'boarder'],
#  "'eoprs": ["rope's", "pore's"],
#  'apsw': ['swap', 'paws', 'wasp'],
#  'achks': ['hacks', 'shack'],
#  "'eglrsu": ["gruel's", "luger's"],
#  'cdelnoos': ['condoles', 'consoled'],
#  'adims': ['maids', 'midas'],
#  'achnos': ['nachos', 'sancho'],
#  'adeilttu': ['altitude', 'latitude'],
#  'gmsu': ['smug', 'gums', 'mugs'],
#  'ahkn': ['khan', 'ankh', 'hank'],
#  'eilm': ['lime', 'mile', 'emil'],
#  'ahkns': ['ankhs', 'shank', 'khans', 'hanks'],
#  'aehns': ['shane', 'ashen'],
#  'ehlps': ['helps', 'shlep'],
#  'noopss': ['snoops', 'spoons'],
#  'acdeirss': ['cressida', 'sidecars'],
#  "'ehkoorssuw": ["housework's", "workhouse's"],
#  'adelrr': ['larder', 'darrel'],
#  'adeeln': ['leaden', 'leaned'],
#  'acehrtt': ['chatter', 'ratchet'],
#  'acdep': ['paced', 'caped'],
#  'inot': ['into', 'toni'],
#  'eemry': ['emery', 'meyer'],
#  'achrst': ['charts', 'starch'],
#  "'emost": ["tome's", "mote's", "moet's"],
#  'ceory': ['royce', 'coyer', 'corey'],
#  'acehkls': ['shackle', 'hackles'],
#  "'deors": ["oder's", "doer's"],
#  'arstw': ['warts', 'straw'],
#  'acegir': ['gracie', 'cagier'],
#  'ips': ['pis', 'sip'],
#  'aginnw': ['awning', 'waning'],
#  'einst': ['stine', 'stein', 'nites', 'tines', 'inset'],
#  'bnory': ['robyn', 'byron', 'bryon'],
#  'ceitv': ['civet', 'evict'],
#  'abgrs': ['garbs', 'brags', 'grabs'],
#  'eehst': ['these', 'thees', 'sheet'],
#  "'acilnsu": ["alcuin's", "lucian's"],
#  'acenrt': ['canter', 'trance', 'recant', 'cretan', 'nectar'],
#  'aemn': ['amen', 'mean', 'name', 'mane'],
#  'deeimprs': ['premised', 'simpered'],
#  'acdehnstu': ['unscathed', 'staunched'],
#  'aefrst': ['strafe', 'faster'],
#  "'ailpsu": ["pauli's", "pilau's"],
#  'adenpps': ['snapped', 'appends'],
#  "'aefst": ["feat's", "feta's", "fate's"],
#  "'oostt": ["otto's", "toot's", "toto's"],
#  'aceilrst': ['articles', 'recitals'],
#  'agny': ['yang', 'nagy'],
#  'glpu': ['gulp', 'plug'],
#  'ajnos': ['sonja', 'jonas', 'jason'],
#  'deeinrsst': ['dissenter', 'residents', 'tiredness'],
#  'adgrs': ['grads', 'drags'],
#  'aachimrs': ['charisma', 'archaism'],
#  'illsy': ['slily', 'silly'],
#  "'agnors": ["groan's", "argon's", "organ's"],
#  'eirst': ['tiers', 'rites', 'tires', 'tries'],
#  'eenoprs': ['openers', 'reopens'],
#  "'eorsv": ["rove's", "over's"],
#  'addens': ['sadden', 'sanded'],
#  'aeprsy': ['payers', 'repays'],
#  'oorst': ['torso', 'roots', 'roost'],
#  'ginoprstu': ['posturing', 'sprouting'],
#  "'erssu": ["ruse's", "user's"],
#  'aeeiilrst': ['israelite', 'realities'],
#  'adginrw': ['drawing', 'warding'],
#  'acegimnrt': ['centigram', 'cremating'],
#  'deerrss': ['dresser', 'redress'],
#  'iklo': ['loki', 'kilo'],
#  'blos': ['lobs', 'slob'],
#  'abtu': ['batu', 'tuba', 'abut', 'tabu'],
#  'ackss': ['casks', 'sacks'],
#  "'abeks": ["beak's", "bake's"],
#  'deegr': ['greed', 'edger'],
#  'deginnrssu': ['undersigns', 'undressing'],
#  'aerstt': ['treats', 'stater', 'taster'],
#  "'ggiknos": ["gingko's", "ginkgo's"],
#  "'aeilmnns": ["lineman's", "melanin's"],
#  'aeiprsu': ['piraeus', 'upraise'],
#  'aanssu': ['susana', 'saunas', 'nassau'],
#  "'aggins": ["nigga's", "aging's"],
#  "'cehinopsst": ["phonetics's", "ctesiphon's"],
#  'deosw': ['dowse', 'sowed'],
#  'acginost': ['agnostic', 'coatings', 'coasting'],
#  'eflorw': ['fowler', 'flower'],
#  "'aainrsst": ["artisan's", "tsarina's", "sinatra's"],
#  'in': ['ni', 'in'],
#  'aeehrrs': ['hearers', 'shearer'],
#  'deilops': ['despoil', 'spoiled'],
#  "'acsst": ["scat's", "acts's", "cast's"],
#  'aekw': ['weak', 'wake'],
#  "'deenrsv": ["vender's", "denver's"],
#  "'ehikrss": ["shriek's", "shrike's"],
#  'egiilnrsv': ['slivering', 'silvering'],
#  'abdeerst': ['debaters', 'breasted'],
#  'dopr': ['drop', 'prod'],
#  "'deiinnosstt": ["distention's", "tendonitis's"],
#  'agghinns': ['gnashing', 'hangings'],
#  "'acenrsv": ["cavern's", "craven's"],
#  "'aegnrrs": ["garner's", "ranger's"],
#  'adenrs': ['sander', 'andres', 'snared'],
#  'ostw': ['stow', 'tows', 'twos'],
#  "'aehrst": ["earth's", "heart's", "hater's", "harte's"],
#  "'abells": ["label's", "bella's"],
#  'aelrs': ['earls', 'reals', 'laser'],
#  "'efhlss": ["flesh's", "shelf's"],
#  'emops': ['poems', 'mopes', 'epsom'],
#  'bhorst': ['broths', 'throbs'],
#  "'ehorst": ["other's", "throe's"],
#  'biorst': ['bistro', 'orbits'],
#  'aaelnprt': ['paternal', 'parental', 'prenatal'],
#  "'ahrst": ["hart's", "thar's"],
#  'deeprtu': ['reputed', 'erupted'],
#  'aceelprs': ['replaces', 'percales'],
#  'aainrsst': ['tsarinas', 'artisans'],
#  'beeefir': ['beefier', 'freebie'],
#  "'delosy": ["doyle's", "yodel's"],
#  'ciopst': ['topics', 'optics'],
#  "'eeerrssv": ["reserve's", "reverse's"],
#  'cot': ['cot', 'oct'],
#  'deilstu': ['duelist', 'dilutes'],
#  'efhiisstt': ['shiftiest', 'fetishist'],
#  "'efins": ["enif's", "fine's"],
#  'aegmnr': ['manger', 'german'],
#  'aijnn': ['ninja', 'jinan'],
#  "'eimprsss": ["premiss's", "impress's"],
#  'acilsv': ['vlasic', 'slavic', 'cavils'],
#  "'adegnrs": ["garden's", "danger's", "gander's"],
#  "'beorsst": ["sorbet's", "strobe's", "osbert's"],
#  "'beors": ["boer's", "bore's", "ebro's", "robe's"],
#  "'ellosvy": ["lovely's", "volley's"],
#  'acenrst': ['recants', 'trances', 'scanter', 'canters'],
#  'aailmn': ['malian', 'manila', 'animal'],
#  "'aehmnrs": ["arnhem's", "herman's"],
#  'eelrstw': ['welters', 'wrestle', 'swelter'],
#  'eikps': ['spike', 'pikes'],
#  'eorsty': ['troyes', 'tyroes', 'storey', 'oyster'],
#  'aeelrsv': ['several', 'reveals'],
#  'ghinnorsu': ['onrushing', 'unhorsing'],
#  'cehst': ['techs', 'chest'],
#  "'admnos": ["nomad's", "damon's"],
#  'bceeehs': ['beeches', 'beseech'],
#  'ddeeirs': ['resided', 'desired', 'derides'],
#  'cdeenor': ['encored', 'encoder'],
#  'enw': ['wen', 'new'],
#  'doors': ['odors', 'doors', 'roods'],
#  'adeiirs': ['dairies', 'diaries'],
#  'agiinrs': ['airings', 'arising', 'raising'],
#  'deenst': ['tensed', 'nested'],
#  'ceehils': ['helices', 'lichees'],
#  'abefllnoopsstu': ['tablespoonfuls', 'tablespoonsful'],
#  'aet': ['eat', 'tea', 'eta', 'ate'],
#  'aegrz': ['gazer', 'graze'],
#  'acenors': ['coarsen', 'corneas'],
#  'eloss': ['soles', 'loses', 'sloes'],
#  'ilpss': ['lisps', 'slips'],
#  'acdekl': ['lacked', 'calked'],
#  'eersstt': ['tersest', 'setters', 'testers', 'streets'],
#  "'eekns": ["keen's", "knee's"],
#  'ilnstu': ['insult', 'sunlit'],
#  "'einsst": ["inset's", "stein's", "stine's"],
#  "'bbinors": ["robbin's", "ribbon's"],
#  "'inoopst": ["potion's", "option's"],
#  "'enost": ["eton's", "tone's", "note's"],
#  "'aceilrst": ["article's", "recital's"],
#  'dilos': ['solid', 'idols'],
#  'ckrstu': ['trucks', 'struck'],
#  'emprs': ['sperm', 'perms'],
#  "'eipprst": ["trippe's", "tipper's"],
#  "'ellssw": ["swell's", "wells's"],
#  'deerst': ['desert', 'rested', 'deters'],
#  'efginrs': ['fingers', 'fringes'],
#  "'egpstu": ["getup's", "puget's"],
#  'aiorsuv': ['saviour', 'various'],
#  'eglos': ['loges', 'ogles'],
#  "'eeiinoprstt": ["petitioner's", "repetition's"],
#  'eimrst': ['remits', 'merits', 'miters', 'timers', 'mister'],
#  "'aelsw": ["wale's", "weal's"],
#  'degirs': ['ridges', 'dirges'],
#  'aeilnr': ['arline', 'linear'],
#  'aehmnr': ['arnhem', 'herman'],
#  'aeilmnn': ['melanin', 'lineman'],
#  'deit': ['tied', 'edit', 'diet', 'tide'],
#  'elorsw': ['rowels', 'slower', 'lowers'],
#  'eisv': ['ives', 'vise', 'vies'],
#  "'aegrs": ["rage's", "gear's"],
#  'aekmrrs': ['remarks', 'markers'],
#  "'aaeiprsst": ["aspirate's", "parasite's"],
#  'cdeeoprrsu': ['reproduces', 'procedures'],
#  'airsstt': ['straits', 'artists'],
#  "'bellosw": ["bowell's", "bellow's"],
#  'acehnsst': ['chastens', 'snatches', 'stanches'],
#  "'aagls": ["alga's", "gala's"],
#  'arst': ['rats', 'star', 'arts', 'tars', 'tsar'],
#  "'ainsst": ["satin's", "stain's", "saint's"],
#  "'ensw": ["wen's", "new's"],
#  'aeilmttu': ['ultimate', 'mutilate'],
#  'accehmno': ['coachmen', 'comanche'],
#  "'abegmnosy": ["bogeyman's", "moneybag's"],
#  'egiimnrt': ['mitering', 'meriting'],
#  'acmor': ['carom', 'macro', 'marco'],
#  'eghilns': ['english', 'shingle'],
#  'abehs': ['hbase', 'sheba'],
#  'abelstt': ['tablets', 'battles'],
#  'ehirs': ['heirs', 'sheri', 'shire', 'hires'],
#  'aamrt': ['tamra', 'marat', 'marta'],
#  "'abils": ["bali's", "bail's"],
#  'ginoppst': ['toppings', 'stopping'],
#  'abiss': ['basis', 'bassi'],
#  'gnow': ['wong', 'gown'],
#  'ahllosw': ['hallows', 'shallow'],
#  'adeehrs': ['headers', 'sheared', 'adheres'],
#  'ffist': ['stiff', 'tiffs'],
#  'aegimnst': ['mangiest', 'steaming'],
#  'cdeinorstu': ['reductions', 'introduces'],
#  'aeflrsu': ['earfuls', 'refusal'],
#  'aefinr': ['efrain', 'fainer'],
#  'aaeiilnorstt': ['retaliations', 'aristotelian'],
#  "'girst": ["trig's", "girt's", "grit's"],
#  'eilnpsu': ['lineups', 'lupines'],
#  "'aalmnsu": ["alumna's", "manual's"],
#  'dhlopu': ['uphold', 'holdup'],
#  'ehlrsstu': ['hustlers', 'ruthless'],
#  "'adelrrs": ["darrel's", "larder's"],
#  'aadn': ['dana', 'adan'],
#  'aessv': ['vases', 'saves'],
#  'elssty': ['slyest', 'styles'],
#  "'begilnsss": ["blessing's", "glibness's"],
#  'cceginnort': ['concreting', 'concerting'],
#  'aenprst': ['parents', 'pastern', 'napster', 'entraps'],
#  "'aaeinoprrst": ["praetorian's", "reparation's"],
#  'beglu': ['bulge', 'bugle'],
#  "'aeiprss": ["spirea's", "praise's", "persia's"],
#  'ehilrt': ['lither', 'hitler'],
#  "'aaceimnrs": ["american's", "cinerama's"],
#  "'aelrssv": ["salver's", "slaver's"],
#  "'aegllrsy": ["allergy's", "gallery's"],
#  'pu': ['pu', 'up'],
#  'aelprtt': ['prattle', 'platter'],
#  'aehrsst': ['rashest', 'trashes'],
#  'eepsw': ['sweep', 'weeps'],
#  'abders': ['breads', 'beards', 'debars'],
#  'aeenrst': ['eastern', 'earnest', 'nearest'],
#  'bin': ['bin', 'nib'],
#  'ilsst': ['slits', 'lists', 'silts'],
#  'abeilor': ['alberio', 'albireo'],
#  'adeelrst': ['lestrade', 'treadles'],
#  'aderrst': ['traders', 'starred', 'retards'],
#  'amn': ['man', 'nam'],
#  'aelmst': ['metals', 'lamest'],
#  "'klooostu": ["outlook's", "lookout's"],
#  'aiilnoopst': ['positional', 'spoliation'],
#  "'ilmos": ["limo's", "milo's"],
#  'aeilrrt': ['retrial', 'trailer'],
#  'achr': ['arch', 'char'],
#  'achiinrst': ['christian', 'christina'],
#  'ehirssw': ['wishers', 'swisher'],
#  'adelm': ['lamed', 'medal'],
#  'adert': ['trade', 'rated', 'tread', 'tared'],
#  'gimpy': ['gimpy', 'pigmy'],
#  'first': ['first', 'rifts'],
#  'alnnu': ['annul', 'luann'],
#  'aeilmss': ['aimless', 'melissa'],
#  'cddeinostu': ['deductions', 'discounted'],
#  'adeilns': ['daniels', 'denials', 'snailed'],
#  "'aclms": ["clam's", "calm's"],
#  'ademsu': ['amused', 'medusa'],
#  'oott': ['otto', 'toot', 'toto'],
#  'aenw': ['wane', 'anew', 'wean'],
#  'ceginrsu': ['rescuing', 'securing'],
#  'aegilnt': ['elating', 'genital', 'gelatin'],
#  'enstu': ['unset', 'tunes'],
#  "'aensv": ["neva's", "nave's", "evan's", "vane's"],
#  "'ablms": ["lamb's", "balm's"],
#  'abderv': ['adverb', 'braved'],
#  'bdeortu': ['obtrude', 'doubter', 'redoubt'],
#  'amnor': ['roman', 'norma', 'moran', 'ramon', 'manor'],
#  "'hosst": ["host's", "shot's"],
#  'aelrsy': ['relays', 'slayer', 'layers'],
#  "'abdeirss": ["sidebar's", "seabird's"],
#  "'oorsst": ["roost's", "torso's"],
#  "'aiinnorstu": ["ruination's", "urination's"],
#  'agimnr': ['ingram', 'margin', 'arming'],
#  'eefl': ['flee', 'feel'],
#  'aderstw': ['strawed', 'steward'],
#  'agnst': ['angst', 'tangs', 'gnats'],
#  'aekst': ['keats', 'stake', 'steak', 'skate', 'teaks', 'takes'],
#  'delmpu': ['plumed', 'lumped'],
#  'eor': ['ore', 'roe'],
#  'aegst': ['gates', 'stage'],
#  'aehlrst': ['halters', 'slather', 'lathers'],
#  'aceil': ['alice', 'celia'],
#  'aabln': ['banal', 'laban'],
#  'acips': ['aspic', 'spica'],
#  'acdepr': ['redcap', 'carped'],
#  "'eilsst": ["islet's", "stile's"],
#  "'aehpss": ["phase's", "shape's"],
#  'ills': ['ills', 'sill'],
#  'adinor': ['ordain', 'dorian', 'inroad'],
#  "'ersty": ["tyre's", "trey's"],
#  'egiors': ['sergio', 'orgies'],
#  'abdeess': ['seabeds', 'debases'],
#  'alostuy': ['layouts', 'outlays'],
#  'eorssty': ['storeys', 'oysters'],
#  'epprsu': ['uppers', 'supper'],
#  'ceeipr': ['pierce', 'recipe'],
#  'adeiinoprtt': ['partitioned', 'trepidation'],
#  'abelm': ['amble', 'blame', 'mabel', 'melba', 'mable'],
#  "'ennost": ["tenon's", "tonne's"],
#  'defloor': ['floored', 'flooder'],
#  "'iiksw": ["wiki's", "kiwi's"],
#  "'adinrs": ["indra's", "nadir's", "drain's", "randi's", "darin's"],
#  'erty': ['tyre', 'trey'],
#  'acdeilms': ['declaims', 'medicals', 'decimals'],
#  'iikw': ['kiwi', 'wiki'],
#  'eilps': ['plies', 'piles', 'spiel'],
#  "'eors": ["ore's", "roe's"],
#  'abeilmr': ['balmier', 'maribel'],
#  "'elops": ["pole's", "lope's", "opel's"],
#  'adeeilm': ['limeade', 'emailed'],
#  'adehlss': ['slashed', 'hassled'],
#  "'giorsv": ["virgo's", "vigor's"],
#  'eorstv': ['voters', 'strove'],
#  'dggiiln': ['gilding', 'gliding'],
#  'deeinr': ['reined', 'denier', 'nereid'],
#  'adefir': ['freida', 'frieda'],
#  'aeeilrstt': ['statelier', 'literates'],
#  "'aceimnrs": ["crimean's", "carmine's"],
#  'aenrss': ['nasser', 'snares'],
#  "'abls": ["alb's", "lab's"],
#  'deiort': ['rioted', 'editor'],
#  'deinors': ['rosined', 'indorse'],
#  'ceeilnost': ['elections', 'selection'],
#  "'elnos": ["leon's", "noel's", "olen's", "leno's"],
#  'glos': ['slog', 'logs'],
#  'emprsttu': ['strumpet', 'trumpets'],
#  "'dsstu": ["stud's", "dust's"],
#  'anor': ['nora', 'oran', 'aron', 'arno', 'roan'],
#  "'ehlorsst": ["holster's", "hostler's"],
#  'cehor': ['chore', 'ochre', 'roche', 'ocher'],
#  'beert': ['ebert', 'beret'],
#  'addegimnn': ['demanding', 'maddening'],
#  'cinos': ['icons', 'coins', 'scion', 'sonic'],
#  'cdeors': ['credos', 'scored', 'decors'],
#  'aegginnr': ['enraging', 'angering'],
#  'cdeir': ['cried', 'riced', 'cider'],
#  "'acdilnors": ["ironclad's", "alcindor's"],
#  'eoprsstt': ['protests', 'spotters'],
#  'aknr': ['rank', 'nark'],
#  'adinors': ['inroads', 'ordains'],
#  'dginos': ['doings', 'dosing'],
#  'illt': ['lilt', 'till'],
#  'eenrrst': ['renters', 'sterner'],
#  'aett': ['teat', 'tate', 'etta'],
#  'eilpry': ['ripley', 'ripely'],
#  'adenr': ['nader', 'arden', 'daren', 'andre'],
#  'adeinst': ['instead', 'detains', 'stained'],
#  'eehinrt': ['therein', 'neither'],
#  "'inprstu": ["turnip's", "turpin's"],
#  'adew': ['awed', 'wade'],
#  "'aeelsst": ["estela's", "teasel's"],
#  'eorrst': ['sorter', 'torres', 'roster', 'resort'],
#  'cgilnosw': ['scowling', 'cowlings'],
#  'alsst': ['salts', 'lasts', 'slats'],
#  'aehlw': ['wheal', 'whale'],
#  'eforsst': ['fosters', 'forests'],
#  'adeegnrs': ['grandees', 'deranges', 'grenades'],
#  'delow': ['lowed', 'dowel'],
#  'adrsy': ['yards', 'drays'],
#  'acenrv': ['craven', 'cavern'],
#  "'iklos": ["kilo's", "loki's"],
#  "'adeelrs": ["dealer's", "leader's"],
#  "'aceilnosst": ["sectional's", "coastline's"],
#  'deirt': ['tired', 'tried'],
#  'acinoss': ['caisson', 'casinos', 'cassino'],
#  "'aansssu": ["nassau's", "susana's"],
#  'deiv': ['vied', 'dive', 'devi'],
#  "'lmpsu": ["plum's", "lump's"],
#  'abelt': ['bleat', 'table'],
#  'abegl': ['gable', 'bagel'],
#  'aellps': ['lapels', 'aspell'],
#  'aabcdeorrsst': ['rebroadcasts', 'broadcasters'],
#  'adekr': ['raked', 'drake'],
#  'abgilmnr': ['rambling', 'marbling'],
#  'eimorst': ['moister', 'mortise'],
#  'fglo': ['golf', 'flog'],
#  'ceefhist': ['chiefest', 'fetiches'],
#  'aeimnrt': ['minaret', 'raiment'],
#  'aeknss': ['sneaks', 'snakes'],
#  "'dehimnoss": ["hedonism's", "sondheim's"],
#  'adelps': ['pleads', 'lapsed', 'pedals'],
#  "'amnors": ["manor's", "norma's", "ramon's", "moran's", "roman's"],
#  'bdeor': ['robed', 'bored'],
#  'aillorstt': ['tortillas', 'littorals'],
#  'deeinrst': ['nerdiest', 'trendies', 'resident', 'dniester', 'inserted'],
#  'aenprt': ['entrap', 'parent'],
#  'adeeinrstt': ['reinstated', 'straitened'],
#  'eeimprsss': ['impresses', 'premisses'],
#  'aegnrr': ['ranger', 'garner'],
#  "'adegrs": ["grade's", "edgar's"],
#  'elosv': ['voles', 'solve', 'loves'],
#  'aaclrvy': ['calvary', 'cavalry'],
#  'deels': ['leeds', 'edsel'],
#  'cdeefiirt': ['certified', 'rectified'],
#  'enops': ['pones', 'opens', 'epson', 'peons'],
#  'bilsy': ['sibyl', 'sybil'],
#  'eegilnst': ['gentiles', 'sleeting', 'steeling'],
#  'deens': ['edens', 'needs', 'dense'],
#  'aefnsst': ['fastens', 'fatness'],
#  'gilnoos': ['loosing', 'soloing'],
#  "'eghins": ["neigh's", "hinge's"],
#  'acensst': ['stances', 'ascents'],
#  'adem': ['mead', 'dame', 'edam', 'made'],
#  'apsty': ['pasty', 'patsy'],
#  'aellrsu': ['laurels', 'allures'],
#  'elotw': ['owlet', 'towel'],
#  'acep': ['pace', 'cape'],
#  'eipps': ['pipes', 'pepsi'],
#  "'aerrsstt": ["starter's", "restart's"],
#  'deffir': ['riffed', 'differ'],
#  'aehrst': ['hearst', 'hearts', 'haters', 'earths'],
#  'ekpsy': ['skype', 'pesky'],
#  "'deos": ["ode's", "doe's"],
#  'einr': ['erin', 'rein'],
#  'aainrst': ['tsarina', 'sinatra', 'artisan'],
#  'dikss': ['skids', 'disks'],
#  'eehirrs': ['rehires', 'sherrie'],
#  'abenrst': ['barents', 'banters'],
#  'aaffir': ['affair', 'raffia'],
#  'aainprst': ['partisan', 'aspirant'],
#  'ciopt': ['topic', 'optic'],
#  'aeeginnrt': ['argentine', 'tangerine'],
#  'aestx': ['taxes', 'texas'],
#  'aaegilnpp': ['appealing', 'lagniappe'],
#  'giiknnp': ['kingpin', 'pinking'],
#  'aeginrst': ['rangiest',
#   'tasering',
#   'gantries',
#   'angriest',
#   'ingrates',
#   'tangiers'],
#  'eimns': ['miens', 'mines'],
#  'amny': ['many', 'myna'],
#  'aanrstt': ['tartans', 'rattans'],
#  'einorst': ['stonier', 'orients'],
#  "'eilns": ["lien's", "line's", "neil's", "nile's"],
#  'aenp': ['pena', 'nape', 'pane'],
#  'aaailnrstu': ['saturnalia', 'australian'],
#  'eiorrst': ['roister', 'rioters'],
#  'afginrt': ['farting', 'rafting'],
#  'ilos': ['soil', 'oils', 'lois', 'silo', 'soli'],
#  "'ailmnopsy": ["olympian's", "palimony's"],
#  'iknos': ['ikons', 'oinks'],
#  'aainprsst': ['aspirants', 'partisans'],
#  'hims': ['shim', 'hims'],
#  'eiprst': ['priest', 'sprite', 'ripest', 'stripe'],
#  'eglru': ['gruel', 'luger'],
#  'defsu': ['feuds', 'fused'],
#  'eeegnr': ['renege', 'greene'],
#  'aenprstt': ['transept', 'patterns'],
#  'ceinpr': ['pincer', 'prince'],
#  "'adeems": ["medea's", "meade's", "edema's"],
#  'aaceglostu': ['coagulates', 'catalogues'],
#  "'alnost": ["alton's", "talon's"],
#  'adnw': ['wand', 'dawn'],
#  'boost': ['boots', 'boost'],
#  "'ailnsv": ["anvil's", "alvin's"],
#  'eeirvw': ['viewer', 'review'],
#  'eilnst': ['silent', 'listen', 'tinsel', 'enlist', 'inlets'],
#  'aehmrst': ['amherst', 'hamster'],
#  'deilmnss': ['mindless', 'mildness'],
#  'aalss': ['salas', 'lassa', 'salsa'],
#  'eegilnr': ['leering', 'reeling'],
#  'adehprs': ['shepard', 'phrased', 'sharped'],
#  "'aeimnors": ["romaine's", "moraine's"],
#  'aersttt': ['tartest', 'tatters'],
#  'eimprss': ['simpers', 'premiss', 'impress'],
#  "'afiilnorstt": ["filtration's", "flirtation's"],
#  'aeiprst': ['parties', 'pastier', 'pirates', 'traipse'],
#  'eiilnoss': ['elisions', 'oiliness'],
#  "'aefkrs": ["faker's", "freak's"],
#  'aceorstv': ['overcast', 'overacts'],
#  'abils': ['basil', 'bails'],
#  "'ehlppss": ["phelps's", "shlepp's"],
#  'cdeeiinrst': ['iridescent', 'indiscreet'],
#  'aelr': ['earl', 'real', 'lear'],
#  'aefhilsst': ['flashiest', 'faithless'],
#  'aceelnru': ['cerulean', 'laurence'],
#  'iklls': ['kills', 'skill'],
#  "'abeilors": ["albireo's", "alberio's"],
#  'dginoow': ['goodwin', 'wooding'],
#  'aelrtv': ['varlet', 'travel'],
#  'einoprt': ['pointer', 'protein'],
#  "'abegls": ["bagel's", "gable's"],
#  'belmorsy': ['sombrely', 'somberly'],
#  'aeilnpr': ['praline', 'plainer'],
#  'adhry': ['hydra', 'hardy'],
#  "'aprsw": ["warp's", "wrap's"],
#  'acers': ['cesar', 'races', 'acres', 'scare', 'cares'],
#  'aelnpt': ['platen', 'planet'],
#  'eelssv': ['vessel', 'selves'],
#  'aemss': ['seams', 'mesas', 'sames'],
#  'aegmr': ['gamer', 'marge'],
#  'aehors': ['ashore', 'hoarse'],
#  'ailosv': ['violas', 'valois'],
#  'aps': ['asp', 'pas', 'sap', 'spa'],
#  "'aekmrrs": ["remark's", "marker's", "kramer's"],
#  'aacorttu': ['actuator', 'autocrat'],
#  "'hknsu": ["kuhn's", "hunk's"],
#  'adinrw': ['darwin', 'inward'],
#  'belmmru': ['brummel', 'mumbler'],
#  "'acenrs": ["crane's", "nacre's"],
#  'aillortt': ['littoral', 'tortilla'],
#  'deeerrsv': ['reversed', 'reserved'],
#  'aalmnu': ['manual', 'alumna'],
#  'adgilnu': ['languid', 'lauding'],
#  "'eilmss": ["selim's", "smile's", "slime's", "miles's"],
#  'ceginotv': ['vietcong', 'coveting'],
#  'adeilpsttu': ['platitudes', 'stipulated'],
#  'ailn': ['lain', 'lina', 'nail'],
#  'elrstu': ['lustre', 'rustle', 'ulster', 'result', 'luster'],
#  'eeloprsty': ['polyester', 'proselyte'],
#  "'eeggirs": ["geiger's", "reggie's"],
#  'abdekr': ['debark', 'braked', 'barked'],
#  'deggru': ['rugged', 'grudge'],
#  'lops': ['slop', 'pols', 'lops'],
#  'aginpprst': ['strapping', 'trappings'],
#  "'egors": ["roeg's", "gore's", "ogre's"],
#  'aceipsst': ['escapist', 'spaciest'],
#  'aelmps': ['sample', 'maples'],
#  "'abesst": ["bates's", "beast's"],
#  'goop': ['goop', 'pogo'],
#  "'eiprsst": ["stripe's", "priest's", "sprite's"],
#  'eimt': ['emit', 'item', 'time', 'mite'],
#  'acepr': ['recap', 'caper', 'crape'],
#  'deefinr': ['refined', 'definer'],
#  'deilst': ['tildes', 'silted', 'listed', 'idlest'],
#  "'adilsv": ["advil's", "vidal's"],
#  'ailv': ['vial', 'vila'],
#  'acdeinoort': ['decoration', 'coordinate'],
#  'amy': ['yam', 'may', 'amy'],
#  'aeehrstt': ['theatres', 'theaters'],
#  "'beinrstu": ["turbine's", "tribune's"],
#  'aeiprss': ['praises', 'spireas', 'aspires'],
#  "'achissty": ["scythia's", "chasity's"],
#  "'dmoos": ["doom's", "odom's", "mood's"],
#  'adeisstt': ['distaste', 'staidest'],
#  'cikls': ['slick', 'licks'],
#  'abgs': ['bags', 'gabs'],
#  'elop': ['lope', 'pole', 'opel'],
#  'aimosst': ['maoists', 'taoisms'],
#  'eeeinprrrstt': ['interpreters', 'reinterprets'],
#  "'aknst": ["tank's", "kant's"],
#  'aelntt': ['talent', 'latent'],
#  "'hosw": ["how's", "who's"],
#  'addelsw': ['swaddle', 'dawdles', 'waddles'],
#  'aemnor': ['monera', 'enamor'],
#  'adegrrs': ['graders', 'regards'],
#  'adeeginrr': ['grenadier', 'rereading'],
#  'beorsw': ['bowers', 'browse'],
#  'ailm': ['mali', 'lima', 'mail'],
#  'adeennrs': ['andersen', 'ensnared'],
#  'dgimnoo': ['dooming', 'domingo'],
#  "'aksy": ["kay's", "yak's"],
#  'bdelott': ['blotted', 'bottled'],
#  'elpsu': ['lepus', 'pulse'],
#  'ego': ['ego', 'geo'],
#  'addemn': ['damned', 'demand', 'madden'],
#  "'aehnsy": ["hyena's", "haney's"],
#  'elnny': ['lenny', 'lynne'],
#  'efilrs': ['lifers', 'rifles', 'fliers'],
#  'deginnrsu': ['sundering', 'undersign'],
#  "'efginrs": ["finger's", "fringe's"],
#  'aaginssy': ['gainsays', 'assaying'],
#  "'ehlost": ["hotel's", "helot's"],
#  'addeeprt': ['predated', 'departed'],
#  'deilv': ['lived', 'devil'],
#  'cdeenortu': ['recounted', 'countered'],
#  'crstu': ['curst', 'crust'],
#  'ehkoorsuw': ['housework', 'workhouse'],
#  'erstuu': ['uterus', 'suture'],
#  'deestw': ['tweeds', 'stewed'],
#  'bennot': ['bonnet', 'benton'],
#  'ahmnu': ['nahum', 'human'],
#  'eimntu': ['minute', 'minuet'],
#  'ainnost': ['nations', 'anoints'],
#  "'adens": ["dane's", "aden's", "dena's", "dean's", "edna's"],
#  'egnor': ['goren', 'goner', 'negro'],
#  "'degilrs": ["glider's", "girdle's"],
#  'bdenoru': ['rebound', 'bounder'],
#  'abdilr': ['ribald', 'bridal'],
#  'lnoos': ['solon', 'olson', 'loons'],
#  'eeipppr': ['peppier', 'preppie'],
#  'aclopsy': ['calypso', 'cosplay'],
#  'aegnrst': ['sargent', 'strange', 'garnets'],
#  'aiprst': ['rapist', 'tapirs'],
#  'enorrtuv': ['turnover', 'overturn'],
#  'ahmnsu': ['humans', 'hamsun'],
#  'degiinnst': ['indigents', 'destining'],
#  'abgr': ['grab', 'brag', 'garb'],
#  'ddeenp': ['pended', 'depend'],
#  "'acilssv": ["vlasic's", "slavic's"],
#  'eginss': ['singes', 'gneiss'],
#  'eehmnoorsw': ['homeowners', 'horsewomen'],
#  'dehinosst': ['hedonists', 'dishonest'],
#  'eil': ['lie', 'lei', 'eli'],
#  "'hoosst": ["shoot's", "sooth's"],
#  'ddeemrru': ['murdered', 'demurred'],
#  'adeerrst': ['serrated', 'retreads', 'arrested'],
#  'adeginrt': ['treading', 'gradient'],
#  'deginn': ['ginned', 'ending'],
#  'abby': ['baby', 'abby'],
#  'acdeno': ['canoed', 'deacon'],
#  'beirst': ['tribes', 'bestir'],
#  'aeinpst': ['sapient', 'panties'],
#  'berstu': ['buster', 'brutes', 'tubers', 'rebuts'],
#  'beikrsst': ['briskest', 'briskets'],
#  'aailv': ['avail', 'avila'],
#  'aehnst': ['hasten', 'athens'],
#  'abdrs': ['bards', 'drabs', 'brads'],
#  'ceeips': ['pieces', 'specie'],
#  'denrs': ['nerds', 'rends'],
#  "'ailrs": ["lair's", "liar's", "lira's", "rail's"],
#  'aegimnrst': ['emigrants', 'mastering', 'streaming'],
#  'aelu': ['eula', 'laue'],
#  'am': ['ma', 'am'],
#  'apsy': ['pays', 'spay', 'yaps'],
#  'alnost': ['alston', 'talons', 'salton'],
#  'efrs': ['refs', 'serf'],
#  'egimnnort': ['mentoring', 'remington'],
#  'eeiqrtu': ['quieter', 'requite'],
#  'eersv': ['sever', 'veers', 'verse', 'serve'],
#  'acdemp': ['camped', 'decamp'],
#  'deelovv': ['evolved', 'devolve'],
#  'aelnrst': ['rentals', 'antlers'],
#  'beegrr': ['gerber', 'berger'],
#  'eegilnrv': ['levering', 'reveling'],
#  'adeilrt': ['trialed', 'trailed'],
#  'ahms': ['hams', 'sham', 'mash'],
#  'irstw': ['writs', 'wrist'],
#  'adeisv': ['visaed', 'advise', 'davies'],
#  'acdeg': ['cadge', 'caged'],
#  'aeeintttv': ['attentive', 'tentative'],
#  'ceert': ['crete', 'erect'],
#  'admnort': ['dormant', 'mordant'],
#  'acginr': ['racing', 'caring', 'arcing'],
#  'eimrs': ['miser', 'mires', 'emirs', 'rimes'],
#  'aaceiilnprstt': ['antiparticles', 'paternalistic'],
#  'aeprssst': ['sparsest', 'trespass'],
#  'abdry': ['brady', 'darby'],
#  'acnnot': ['canton', 'cannot'],
#  'adegilns': ['signaled', 'dealings'],
#  'bors': ['orbs', 'robs'],
#  "'egnors": ["goren's", "negro's", "goner's"],
#  'enorss': ['snores', 'sensor'],
#  "'aclsy": ["clay's", "lacy's"],
#  'aaenpst': ['anapest', 'peasant'],
#  'eimrt': ['timer', 'miter', 'merit', 'remit'],
#  'eeeilrst': ['leeriest', 'steelier'],
#  'ccikloy': ['cockily', 'colicky'],
#  'aclo': ['coal', 'cola'],
#  'adev': ['dave', 'veda'],
#  'eeforrst': ['reforest', 'forester'],
#  'deorstu': ['dourest', 'detours'],
#  "'eilnsst": ["silent's", "tinsel's", "listen's"],
#  'aosstt': ['stoats', 'toasts'],
#  'ceiinnopst': ['inspection', 'inceptions'],
#  'ceefprt': ['perfect', 'prefect'],
#  'aacnpst': ['catnaps', 'capstan'],
#  'aelsstt': ['saltest', 'stalest'],
#  "'ckors": ["kroc's", "rock's", "cork's"],
#  "'cerssu": ["curse's", "sucre's"],
#  'eeinrstv': ['nerviest', 'reinvest'],
#  'aaclr': ['carla', 'clara'],
#  'aey': ['aye', 'yea'],
#  'enosy': ['noyes', 'nosey'],
#  'aceerrt': ['caterer', 'terrace', 'retrace'],
#  'ckstu': ['stuck', 'tucks'],
#  'allot': ['atoll', 'allot'],
#  "'aginpprsst": ["trappings's", "strapping's"],
#  "'aalns": ["alan's", "lana's"],
#  'aeipsst': ['pasties', 'patsies'],
#  "'acegnsy": ["agency's", "cagney's"],
#  'eefrst': ['freest', 'fester'],
#  "'inopst": ["pinto's", "piton's", "point's"],
#  'aeilrty': ['irately', 'reality'],
#  "'bnsu": ["bun's", "nub's"],
#  'akos': ['oaks', 'soak'],
#  "'aehrss": ["shear's", "share's"],
#  'cgimmnsu': ['scumming', 'cummings'],
#  "'aeinsv": ["evian's", "nivea's"],
#  'acegors': ['corsage', 'cargoes'],
#  'deginns': ['sending', 'endings'],
#  'ehins': ['hines', 'shine'],
#  'lostu': ['louts', 'lotus'],
#  'acdnor': ['candor', 'conrad', 'dacron'],
#  'glsu': ['slug', 'lugs'],
#  'eimnnrsttu': ['nutriments', 'instrument'],
#  'adegnrr': ['gardner', 'grander'],
#  'ikrs': ['risk', 'irks', 'kris'],
#  'adeinrsst': ['streisand', 'tardiness'],
#  'cenors': ['crones', 'censor'],
#  'aekls': ['leaks', 'slake', 'lakes'],
#  'deiltt': ['titled', 'tilted'],
#  'eprsttu': ['sputter', 'putters'],
#  "'aaprsst": ["satrap's", "sparta's"],
#  'adeepprr': ['prepared', 'dapperer'],
#  'acel': ['lace', 'alec'],
#  'aegilmnr': ['malinger', 'germinal'],
#  'anruwy': ['runway', 'unwary'],
#  'rsstu': ['rusts', 'truss'],
#  'aeghilnrt': ['haltering', 'earthling', 'lathering'],
#  "'einprrst": ["printer's", "reprint's"],
#  'eoqtu': ['toque', 'quote'],
#  'abiklmns': ['lambskin', 'lambkins'],
#  "'apssty": ["pasty's", "patsy's"],
#  'accilno': ['laconic', 'conical'],
#  "'blost": ["blot's", "bolt's"],
#  'elmnot': ['molten', 'melton'],
#  'aeksst': ['steaks', 'stakes', 'skates'],
#  'acenos': ['canoes', 'oceans'],
#  'cloo': ['cool', 'loco'],
#  'aegirt': ['gaiter', 'triage'],
#  'cchiks': ['schick', 'chicks'],
#  "'acers": ["care's", "race's", "acre's"],
#  "'amsy": ["may's", "amy's", "yam's"],
#  'adeilt': ['dilate', 'detail', 'tailed'],
#  "'aelorsvy": ["overlay's", "layover's"],
#  'eenrsv': ['severn', 'nerves'],
#  'celoost': ['ocelots', 'coolest'],
#  'emoorr': ['romero', 'roomer'],
#  'adekns': ['kneads', 'snaked'],
#  'aeilnrt': ['reliant', 'latiner', 'retinal', 'latrine'],
#  'alosv': ['ovals', 'salvo'],
#  "'aemss": ["mesa's", "seam's"],
#  'inpss': ['snips', 'spins'],
#  "'elpssu": ["pulse's", "lepus's"],
#  "'elossu": ["louse's", "seoul's"],
#  'eeir': ['erie', 'eire'],
#  'eorssu': ['rouses', 'serous'],
#  'ginortu': ['routing', 'touring'],
#  'eeenprst': ['pretense', 'preteens', 'petersen'],
#  'gimnpu': ['impugn', 'umping'],
#  'aeglmn': ['mangle', 'legman'],
#  'delop': ['poled', 'loped'],
#  'aciltty': ['tacitly', 'cattily'],
#  'einrsu': ['inures', 'insure'],
#  'deeersv': ['severed', 'deserve'],
#  'eeffjry': ['jeffery', 'jeffrey'],
#  'abstu': ['tabus', 'abuts', 'tubas'],
#  "'opsst": ["stop's", "spot's", "post's"],
#  'amory': ['mayor', 'moray'],
#  "'agnst": ["tang's", "gnat's"],
#  'eeggir': ['reggie', 'geiger'],
#  "'eeloprssty": ["polyester's", "proselyte's"],
#  'deirstv': ['strived', 'diverts'],
#  'cciirt': ['critic', 'citric'],
#  'bbelrsu': ['burbles', 'lubbers'],
#  'ehinrss': ['shiners', 'shrines'],
#  'cino': ['icon', 'coin'],
#  'ceinorstu': ['cretinous', 'neurotics', 'countries'],
#  'aacdeglotu': ['coagulated', 'catalogued'],
#  "'elosv": ["vole's", "love's"],
#  'aeemns': ['seamen', 'enemas'],
#  "'aeekmrs": ["remake's", "kareem's"],
#  'eors': ['sore', 'eros', 'roes', 'ores', 'rose'],
#  'aally': ['allay', 'layla'],
#  'beilrst': ['bristle', 'blister'],
#  'adeeeglrv': ['leveraged', 'everglade'],
#  'aelrst': ['staler', 'alerts', 'alters', 'slater', 'salter'],
#  'eiinopstt': ['pointiest', 'petitions'],
#  "'aegrrst": ["garter's", "grater's", "garret's"],
#  'denu': ['nude', 'dune'],
#  'adenpt': ['panted', 'pedant'],
#  "'ceorsy": ["corey's", "royce's"],
#  'aeerst': ['easter', 'eaters', 'teaser', 'teresa'],
#  'adel': ['leda', 'lade', 'lead', 'dale', 'deal'],
#  'befirs': ['briefs', 'fibers'],
#  'elpst': ['slept', 'pelts', 'spelt'],
#  'epsstu': ['upsets', 'setups'],
#  "'ceeorrssu": ["recourse's", "resource's"],
#  "'adeils": ["ideal's", "delia's"],
#  'aginoprrt': ['prorating', 'parroting'],
#  "'abelrrsw": ["warbler's", "brawler's"],
#  'einrst': ['insert', 'inters'],
#  'aelnrtu': ['renault', 'laurent', 'neutral'],
#  "'''cefloss": ["fo'c'sle's", "fo'c's'les"],
#  'giilntt': ['tilting', 'tlingit', 'titling'],
#  'gstu': ['tugs', 'gust', 'guts'],
#  'cersw': ['screw', 'crews'],
#  'eginrss': ['resigns', 'singers', 'ingress', 'signers'],
#  'aeglr': ['large', 'regal', 'alger', 'lager', 'glare', 'elgar'],
#  'adinr': ['indra', 'nadir', 'randi', 'drain', 'darin'],
#  "'acelrs": ["clare's", "clear's"],
#  "'aaegmnst": ["magenta's", "magnate's"],
#  'aeemnssttt': ['testaments', 'statements'],
#  "'adiils": ["lidia's", "iliad's"],
#  'acem': ['mace', 'acme', 'came'],
#  'addeest': ['sedated', 'deadest'],
#  'eefilst': ['lefties', 'liefest'],
#  'adeinnoostt': ['denotations', 'detonations'],
#  "'enosst": ["stone's", "seton's", "onset's"],
#  "'begins": ["binge's", "begin's", "being's"],
#  'adeehr': ['adhere', 'header'],
#  'aeimorstz': ['atomizers', 'amortizes'],
#  "'derrsy": ["dryer's", "ryder's"],
#  'aegpr': ['pager', 'grape'],
#  "'aainprsst": ["partisan's", "aspirant's"],
#  'aceilprs': ['calipers', 'replicas'],
#  "'eggilrsw": ["wriggle's", "wiggler's"],
#  "'aelnos": ["leona's", "oneal's"],
#  'emsu': ['muse', 'emus'],
#  'aeegimnprt': ['permeating', 'impregnate'],
#  "'adnrstu": ["durant's", "tundra's"],
#  'eginrs': ['resign', 'ingres', 'reigns', 'signer', 'singer'],
#  "'aeijms": ["jamie's", "mejia's", "jaime's"],
#  "'acprs": ["crap's", "carp's"],
#  "'acenrst": ["trance's", "nectar's", "canter's", "cretan's"],
#  'aepsst': ['pastes', 'spates'],
#  'belmrstu': ['tumblers', 'stumbler', 'tumbrels'],
#  'eiinnstt': ['tientsin', 'tinniest'],
#  "'deilorss": ["soldier's", "deloris's"],
#  "'eghilnss": ["english's", "shingle's"],
#  'acddeeimt': ['decimated', 'medicated'],
#  "'ceorsst": ["corset's", "escort's", "cortes's", "sector's"],
#  'adimost': ['diatoms', 'mastoid'],
#  "'alnos": ["loan's", "nola's"],
#  'eflt': ['felt', 'left'],
#  'aerrs': ['serra', 'rares', 'rears'],
#  'eeprs': ['spree', 'peers', 'speer'],
#  'eeinrst': ['steiner', 'entries'],
#  'cdeeers': ['recedes', 'decrees'],
#  'aeksw': ['wakes', 'wesak', 'askew'],
#  'bsu': ['bus', 'sub', 'ubs'],
#  'giprs': ['sprig', 'grips', 'prigs'],
#  'begins': ['begins', 'binges', 'beings'],
#  'ainrstt': ['tristan', 'transit'],
#  "'egilmmns": ["lemming's", "memling's"],
#  "'aceps": ["pace's", "cape's"],
#  'aacinorst': ['raincoats', 'croatians'],
#  'aabmnst': ['bantams', 'batsman'],
#  'air': ['air', 'ira'],
#  'abilopr': ['bipolar', 'parboil'],
#  'aehrsw': ['washer', 'hawser'],
#  "'ilnos": ["loin's", "lion's", "olin's"],
#  'deenrtu': ['denture', 'tenured'],
#  'iprsu': ['prius', 'sirup'],
#  'aceeinnrt': ['ancienter', 'nectarine'],
#  'abddins': ['sindbad', 'disband'],
#  'deinns': ['sinned', 'dennis'],
#  'ehlrstu': ['hustler', 'hurtles'],
#  'aegimrt': ['ragtime', 'maigret', 'migrate'],
#  "'emorss": ["mores's", "morse's"],
#  'loos': ['solo', 'oslo'],
#  'aaceilrsv': ['cavaliers', 'cavalries'],
#  "'defils": ["fidel's", "field's"],
#  'acosst': ['coasts', 'ascots'],
#  'adimst': ['admits', 'amidst'],
#  'delos': ['lodes', 'doles', 'soled'],
#  'einsst': ['steins', 'insets'],
#  'dhlopsu': ['upholds', 'holdups'],
#  "'ahhss": ["hash's", "shah's"],
#  'aeirsstt': ['artistes', 'artsiest'],
#  'delosw': ['dowels', 'slowed'],
#  'adehlt': ['lathed', 'halted'],
#  "'aders": ["dear's", "read's", "dare's"],
#  "'aersw": ["wear's", "ware's"],
#  'cdeeilns': ['licensed', 'silenced', 'declines'],
#  "'adhrsy": ["hardy's", "hydra's"],
#  'egiimmnrs': ['immersing', 'simmering'],
#  'orst': ['tors', 'sort', 'rots'],
#  'notw': ['wont', 'town'],
#  'ensw': ['news', 'wens', 'sewn'],
#  'aceprst': ['carpets', 'spectra'],
#  'aensw': ['weans', 'wanes'],
#  'ails': ['ails', 'sail', 'lisa'],
#  'achmo': ['macho', 'mocha'],
#  'eeiimprssv': ['impressive', 'permissive'],
#  'aer': ['ear', 'are', 'rae', 'era'],
#  'ailss': ['sisal', 'sails', 'silas'],
#  "'adinsv": ["dvina's", "divan's", "viand's"],
#  ...}

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
sorted(more_than_one, key=lambda x:len(more_than_one[x]), reverse=True)
# Out:
# ['aelst',
#  'acerst',
#  'aeprs',
#  'aekst',
#  'aeginrst',
#  'aeglr',
#  'aelpst',
#  'abest',
#  'acorst',
#  'adeprs',
#  'acert',
#  'aelps',
#  'adens',
#  'aerst',
#  'aels',
#  'opst',
#  'aemst',
#  'aden',
#  'aeprss',
#  'einst',
#  'acenrt',
#  'eimrst',
#  'arst',
#  'amnor',
#  'abelm',
#  "'adinrs",
#  'anor',
#  "'amnors",
#  'deeinrst',
#  'ilos',
#  'eilnst',
#  'acers',
#  'elrstu',
#  "'adens",
#  'eors',
#  'aelrst',
#  'adel',
#  'adinr',
#  'eginrs',
#  'elno',
#  'eerst',
#  'enos',
#  'aemns',
#  'adnor',
#  'abder',
#  'aelm',
#  'adeegnr',
#  'aers',
#  'aest',
#  'aehls',
#  'acder',
#  "'anors",
#  "'aeglrs",
#  'eiprsst',
#  'eilv',
#  'aeinrrst',
#  'enorst',
#  'aepr',
#  'aepst',
#  'abel',
#  "'abelms",
#  "'aelms",
#  'adeknr',
#  "'elrsstu",
#  "'aelnors",
#  'aehrs',
#  'aelms',
#  'aprst',
#  'aesst',
#  'aelpt',
#  'aelprsy',
#  'adelst',
#  'eimst',
#  'aderrw',
#  'adehrst',
#  'aorst',
#  "'aelsst",
#  'eenrst',
#  'enost',
#  'aegilnrt',
#  'aelnor',
#  'aceprs',
#  'abers',
#  'eilms',
#  'acost',
#  'eoprs',
#  'einrs',
#  'agnors',
#  'gilnos',
#  'ehlost',
#  'deor',
#  'bstu',
#  'deorst',
#  'eiknrst',
#  'eno',
#  'enrst',
#  'adelor',
#  'ahkns',
#  'aemn',
#  'eirst',
#  'abtu',
#  "'aehrst",
#  "'beors",
#  'acenrst',
#  'eorsty',
#  'aet',
#  'eersstt',
#  'deit',
#  'ehirs',
#  'aenprst',
#  'adert',
#  "'aensv",
#  "'elnos",
#  'cehor',
#  'cinos',
#  'adenr',
#  'eorrst',
#  'enops',
#  'adem',
#  'aehrst',
#  "'eilns",
#  'eiprst',
#  'aeiprst',
#  'aps',
#  "'eilmss",
#  'eimt',
#  'deilst',
#  'berstu',
#  "'ailrs",
#  'eersv',
#  'eimrs',
#  'eimrt',
#  'aeilnrt',
#  'aeerst',
#  'eginrss',
#  "'acenrst",
#  "'ceorsst",
#  'aer',
#  "'aelns",
#  'aelsst',
#  'aeprt',
#  'ceops',
#  "'enos",
#  'acst',
#  'adeis',
#  'hstu',
#  'aeelmnss',
#  'aelp',
#  'eersst',
#  'deist',
#  'aehprs',
#  "'aimrs",
#  'aginprs',
#  'einps',
#  "'adenrs",
#  'elos',
#  "'adnors",
#  "'aelss",
#  'desu',
#  'aeiprs',
#  'aelmny',
#  'eimr',
#  'inopst',
#  'adeprt',
#  'cdeersu',
#  "'aehprss",
#  'abelst',
#  'deinw',
#  'adeiln',
#  'adenrw',
#  'eilnsst',
#  'deirs',
#  'adeerr',
#  'adeiprs',
#  'aeginrt',
#  'dehors',
#  "'aelpst",
#  'adels',
#  'arsty',
#  'adegnr',
#  'anps',
#  "'eimrs",
#  'efirst',
#  "'aers",
#  'aeeirstt',
#  'beirsu',
#  'aeinprst',
#  'aenr',
#  'defil',
#  'ersu',
#  'cenorstu',
#  'deils',
#  'eirs',
#  'adeimn',
#  'ainst',
#  'iorst',
#  'belstu',
#  'acelprs',
#  'aprt',
#  "'aelsv",
#  'efilst',
#  'abdelm',
#  "'adenss",
#  'aimr',
#  'aersst',
#  'aenv',
#  'eiln',
#  'enst',
#  'enop',
#  'egor',
#  "'aeksst",
#  "'eorrsst",
#  'aprs',
#  "'eirst",
#  "'cehors",
#  'adehs',
#  'aeln',
#  'aeginrr',
#  'ailr',
#  'ceorst',
#  'deiorst',
#  'aelpry',
#  "'aelps",
#  'abst',
#  'deginor',
#  'aaimnr',
#  'abet',
#  'aehr',
#  'loops',
#  "'adeimns",
#  'adepr',
#  'aderrsw',
#  'alps',
#  'aerv',
#  'aerrst',
#  'beor',
#  'adeelrt',
#  'apst',
#  'aelnp',
#  'efil',
#  'aeirs',
#  'aelt',
#  "'abels",
#  'agilnst',
#  'aeirstt',
#  'gnsu',
#  'eilsv',
#  'aegllry',
#  'alst',
#  'eforst',
#  "'aaimnrs",
#  "'adels",
#  'aelry',
#  'aelmnt',
#  'eeerrsv',
#  'ademn',
#  'aenrs',
#  'aelv',
#  'aegln',
#  'aglno',
#  'ailrs',
#  'adeoprrt',
#  'inps',
#  'deiopst',
#  'aent',
#  'acdeilm',
#  'aemt',
#  'beors',
#  'ceorssu',
#  'agiknst',
#  'eirt',
#  'degins',
#  'acehst',
#  'apss',
#  'aeiprrs',
#  'aehrt',
#  'deinnt',
#  'acders',
#  'aeglrs',
#  'aelnps',
#  'acellrs',
#  'aflo',
#  'eerstt',
#  "'eersstt",
#  "'egorrs",
#  'abls',
#  "'aalrs",
#  'eikln',
#  'adil',
#  'einprrst',
#  "'abdrs",
#  "'aenps",
#  'aors',
#  'acersst',
#  'aceinsstt',
#  'ehirtw',
#  'deoprstu',
#  'below',
#  'apsw',
#  'gmsu',
#  'ahkn',
#  'eilm',
#  "'emost",
#  'ceory',
#  'bnory',
#  'abgrs',
#  'eehst',
#  "'aefst",
#  "'oostt",
#  'ajnos',
#  'deeinrsst',
#  "'agnors",
#  'oorst',
#  'aerstt',
#  'aanssu',
#  'acginost',
#  "'aainrsst",
#  "'acsst",
#  'adenrs',
#  'ostw',
#  'aelrs',
#  'emops',
#  'aaelnprt',
#  'acilsv',
#  "'adegnrs",
#  "'beorsst",
#  'aailmn',
#  'eelrstw',
#  'ddeeirs',
#  'doors',
#  'agiinrs',
#  'eloss',
#  "'einsst",
#  "'enost",
#  'deerst',
#  'elorsw',
#  'eisv',
#  'acehnsst',
#  "'ainsst",
#  'acmor',
#  'aamrt',
#  'adeehrs',
#  "'girst",
#  "'aeiprss",
#  'abders',
#  'aeenrst',
#  'ilsst',
#  'aderrst',
#  'adeilns',
#  'oott',
#  'aenw',
#  'aegilnt',
#  'bdeortu',
#  'aelrsy',
#  'agimnr',
#  'agnst',
#  'aehlrst',
#  'adinor',
#  'acdeilms',
#  'eilps',
#  "'elops",
#  'deeinr',
#  'cdeors',
#  'cdeir',
#  'aett',
#  'adeinst',
#  'alsst',
#  'adeegnrs',
#  'acinoss',
#  'deiv',
#  'adelps',
#  'elosv',
#  'eegilnst',
#  'deens',
#  'aainrst',
#  'aenp',
#  "'adeems",
#  'aalss',
#  'adehprs',
#  'eimprss',
#  'aelr',
#  'aemss',
#  "'aekmrrs",
#  'ailn',
#  'abdekr',
#  'lops',
#  "'egors",
#  "'eiprsst",
#  'acepr',
#  'amy',
#  'aeiprss',
#  "'dmoos",
#  'elop',
#  'addelsw',
#  'ailm',
#  'addemn',
#  'efilrs',
#  'egnor',
#  'lnoos',
#  'aegnrst',
#  'abgr',
#  'eil',
#  'adeerrst',
#  'abdrs',
#  'aegimnrst',
#  'apsy',
#  'alnost',
#  'ahms',
#  'adeisv',
#  'acginr',
#  "'egnors",
#  "'eilnsst",
#  "'ckors",
#  'aceerrt',
#  "'inopst",
#  'acdnor',
#  'ikrs',
#  'aekls',
#  'aeghilnrt',
#  'aeksst',
#  "'acers",
#  "'amsy",
#  'adeilt',
#  'eeenprst',
#  'abstu',
#  "'opsst",
#  'ceinorstu',
#  "'aegrrst",
#  'elpst',
#  'aelnrtu',
#  'giilntt',
#  'gstu',
#  'acem',
#  "'enosst",
#  "'begins",
#  "'aeijms",
#  'belmrstu',
#  'aerrs',
#  'eeprs',
#  'aeksw',
#  'bsu',
#  'giprs',
#  'begins',
#  "'ilnos",
#  'aegimrt',
#  'delos',
#  "'aders",
#  'cdeeilns',
#  'orst',
#  'ensw',
#  'ails',
#  'ailss',
#  "'adinsv",
#  'bertu',
#  'deirw',
#  'aeginnt',
#  "'aeinprs",
#  'oprstu',
#  'acelpr',
#  "'aehrs",
#  'amr',
#  'abgilmn',
#  "'iorst",
#  'loop',
#  'adegln',
#  'aim',
#  'ehors',
#  'illst',
#  'ddeelu',
#  'aadin',
#  "'aersst",
#  'aagr',
#  'amps',
#  "'aeimnrssu",
#  'abdeert',
#  'eorrsst',
#  'hoost',
#  'certu',
#  "'ceopss",
#  "'aalsss",
#  'aept',
#  'elmo',
#  'ader',
#  'aehlst',
#  'deno',
#  'adeilr',
#  "'aegorst",
#  'eenrv',
#  'aefrs',
#  'abdelst',
#  'deimr',
#  'alo',
#  "'aessty",
#  'aehl',
#  'flosw',
#  "'bnossu",
#  'adeest',
#  'deers',
#  "'eimrst",
#  'acr',
#  'ehos',
#  'den',
#  "'acerst",
#  'abeillrs',
#  "'adems",
#  'elops',
#  'eoprstu',
#  'eenprsst',
#  'abinr',
#  'deeilrv',
#  "'efils",
#  'ceinst',
#  'ainr',
#  'aeegnrsst',
#  'aghs',
#  'amost',
#  'apt',
#  'orty',
#  'deeirs',
#  'aelmpr',
#  'deeelst',
#  "'eoprss",
#  "'eersst",
#  'aekmrr',
#  'eirsw',
#  "'abgrs",
#  'aeinrv',
#  "'aemrs",
#  'aalmr',
#  'aeimnrs',
#  'aclor',
#  'dehor',
#  'cdeor',
#  'inst',
#  'eels',
#  'aceinnst',
#  "'aemst",
#  'adesw',
#  'anors',
#  'agnor',
#  "'abinrs",
#  'abeert',
#  'aeelrs',
#  "'amrs",
#  'cdeikr',
#  'afrst',
#  "'aceimrs",
#  "'aissv",
#  'aegrrst',
#  'ceikrst',
#  'acmors',
#  'acdeinotu',
#  "'enorsst",
#  'iloss',
#  'ginsu',
#  'aegmnost',
#  'deiorrw',
#  'aimor',
#  'eenprst',
#  'ehnor',
#  'acer',
#  'abehr',
#  "'ceeprsst",
#  'aeinstv',
#  'degiint',
#  'eiprs',
#  "'acnorst",
#  "'oprsstu",
#  'aegilnry',
#  "'adlnors",
#  'giimnst',
#  'eprsy',
#  'aairt',
#  "'aemns",
#  'aders',
#  'opt',
#  'degilnu',
#  "'ainst",
#  'aesy',
#  'loost',
#  'einrt',
#  "'aims",
#  'hops',
#  'aeorstt',
#  'beorst',
#  'aemrs',
#  'ackls',
#  'essu',
#  'aeegnrst',
#  'deilos',
#  'deos',
#  'abels',
#  'eorsv',
#  'aeehrst',
#  "'bssu",
#  'aegs',
#  "'abekrs",
#  'ant',
#  'amnors',
#  'aeinv',
#  "'eehrst",
#  "'doors",
#  'aelprst',
#  "'almnors",
#  'ikns',
#  "'apss",
#  "'alos",
#  'aeils',
#  'adm',
#  'aceilsst',
#  'einsw',
#  'hrtu',
#  "'moors",
#  "'aersv",
#  'cehikstt',
#  'eoprst',
#  'apr',
#  "'aegrst",
#  'deeirsv',
#  'aems',
#  "'alsst",
#  'dmoos',
#  'aisv',
#  'art',
#  'eiorsst',
#  'eekls',
#  'aeill',
#  'aber',
#  "'aceprs",
#  'aehils',
#  'aegrrt',
#  'orstu',
#  'aestt',
#  'celru',
#  'eers',
#  'lmpsu',
#  'hortw',
#  "'aclors",
#  'aeimnrsu',
#  'gins',
#  'aceps',
#  'adegrr',
#  'eelrstt',
#  'aehps',
#  "'eenrstu",
#  "'acelprs",
#  'nosw',
#  'aelmnst',
#  'acdenst',
#  'acdeert',
#  "'loops",
#  'deiorsw',
#  'adrsw',
#  'aceehrst',
#  'ghnostu',
#  'adeelnr',
#  'deil',
#  'aeps',
#  'aesty',
#  'ailns',
#  "'agins",
#  'emost',
#  'ahsw',
#  'opsst',
#  'eemt',
#  'estw',
#  'egors',
#  'bnsu',
#  'aert',
#  'oprst',
#  'adeils',
#  'aeelps',
#  'aint',
#  'ilps',
#  'acehlst',
#  'acdeenrt',
#  'aegimr',
#  'aeginrs',
#  'beeorsv',
#  "'cirsstu",
#  "'afrst",
#  "'aepst",
#  "'aehst",
#  "'aderrsw",
#  'adeerst',
#  'cilo',
#  'ehikrs',
#  'aeehrtw',
#  'aegmn',
#  'agilnps',
#  'aceimr',
#  'ceeiprs',
#  'aersw',
#  'airst',
#  'abesst',
#  'acdert',
#  'aekl',
#  "'aairst",
#  "'einpss",
#  'deir',
#  'ceorsu',
#  'aehrss',
#  'aeht',
#  "'abehrs",
#  'adilorty',
#  'acrs',
#  'aceerrst',
#  "'aamrst",
#  "'aelnps",
#  'cginorsu',
#  "'acost",
#  'alsw',
#  "'aaeimnnrs",
#  'aceginrrt',
#  'elostw',
#  'ahlst',
#  "'adeinns",
#  'aegilnrst',
#  "'adms",
#  'adefrt',
#  'achnst',
#  'aprsy',
#  'agns',
#  'ehmorst',
#  'acehrs',
#  'aclors',
#  'aegmnot',
#  'eenrstu',
#  "'aorsst",
#  'lost',
#  'aegimns',
#  'adenrsw',
#  "'amrsy",
#  'anst',
#  'aabdor',
#  'deloos',
#  'ceehrst',
#  'aiprs',
#  'derstu',
#  "'aprst",
#  'acdeerrt',
#  'adders',
#  'egiilnnst',
#  "'aeersst",
#  'adeinn',
#  'ceeprsst',
#  'deins',
#  'deopst',
#  'dorwy',
#  "'ahkns",
#  'almps',
#  'aclps',
#  "'demos",
#  'ahlsu',
#  'aeilns',
#  'emors',
#  'deortu',
#  "'eirss",
#  'egiorst',
#  'ennost',
#  'aelprsst',
#  'adilv',
#  "'eimst",
#  'aenrrt',
#  "'dinos",
#  "'aceehrst",
#  'aefst',
#  'abdir',
#  'ilopst',
#  'hostu',
#  'abelry',
#  'eehnorw',
#  'deis',
#  'eils',
#  'dino',
#  "'aekls",
#  'alms',
#  'hist',
#  'eoprstt',
#  "'aeilss",
#  'cirstu',
#  'adeefst',
#  'adelors',
#  'diks',
#  "'ceorssu",
#  'deesw',
#  "'aegmnost",
#  'aegrs',
#  'demos',
#  'deloop',
#  'aepry',
#  'adest',
#  "'aprs",
#  'ail',
#  'cdeorsu',
#  "'aelst",
#  'ahstw',
#  'abeirs',
#  'cerstu',
#  'aehst',
#  "'deist",
#  'btu',
#  'eopss',
#  "'anst",
#  "'bnorsy",
#  'ilst',
#  "'adelors",
#  "'eginrss",
#  'nstu',
#  'ceorsst',
#  'bdeorstu',
#  'deeginrs',
#  'abdegr',
#  'adegnrs',
#  'acems',
#  'begin',
#  'aenot',
#  'acilopt',
#  'bbelru',
#  "'eiknrsst",
#  'aaeimnnr',
#  "'pssu",
#  "'abstu",
#  'abdeirs',
#  'aeilnst',
#  "'einrss",
#  'deirv',
#  'aerstw',
#  "'enops",
#  "'aerst",
#  'eiorrsst',
#  "'ajnoss",
#  'alnos',
#  'aeinprt',
#  'aeinrst',
#  'abegiln',
#  'deeinv',
#  "'ceimssu",
#  "'aeglns",
#  'ceimsu',
#  'eerw',
#  'eloruv',
#  'aeilms',
#  'adeenr',
#  'aegort',
#  "'aailmns",
#  "'aeills",
#  'cnostu',
#  'abekr',
#  'eggiln',
#  'aeiprsst',
#  "'aegmns",
#  'abdr',
#  'aaln',
#  'eeilnrst',
#  "'ainrs",
#  'aelpss',
#  'ilno',
#  'amrs',
#  'aelrstt',
#  'belrstu',
#  'aailmns',
#  'aceginrt',
#  'anry',
#  'amrst',
#  "'eglos",
#  'agls',
#  'aeilrst',
#  'aeelst',
#  'adegr',
#  'ipst',
#  'deinrs',
#  "'adehrst",
#  'eglo',
#  'iort',
#  "'acmors",
#  'flow',
#  "'amnos",
#  'einsv',
#  'dis',
#  "'aehilss",
#  "'amps",
#  'abdeinr',
#  "'flosw",
#  'deenrv',
#  'ailnst',
#  'aegrt',
#  'aekps',
#  'deeforst',
#  "'aelnrstu",
#  'eggilns',
#  "'aelprsy",
#  'aegnrs',
#  'iklns',
#  'girst',
#  'cehir',
#  'abehrt',
#  "'deirsv",
#  "'ailms",
#  "'aelrsy",
#  'egiinprrs',
#  'acelrt',
#  'acnort',
#  'einrss',
#  'dmoo',
#  'eilst',
#  'aerstv',
#  'belmrsu',
#  'einstu',
#  'deikln',
#  'eeprsu',
#  'alnot',
#  'adeem',
#  'cdlos',
#  'ceilmops',
#  "'adegrrs",
#  "'aestt",
#  "'aglnos",
#  'gory',
#  "'acrs",
#  "'aekst",
#  "'efilrs",
#  "'eilsv",
#  'adder',
#  'efilr',
#  'orsty',
#  'epst',
#  "'abegilns",
#  "'achins",
#  'aalr',
#  "'ehnors",
#  "'eils",
#  'moor',
#  'cost',
#  'elnor',
#  'eilnoss',
#  'eghhist',
#  "'elorsuv",
#  "'eilms",
#  'asw',
#  'eeinrtu',
#  'ehnorst',
#  "'ehnorst",
#  'aelnors',
#  'ademnru',
#  'eeginrst',
#  "'dens",
#  'eiimnrt',
#  'airstt',
#  'cdeinrs',
#  'dehrs',
#  "'aalmrs",
#  "'aflos",
#  'deilw',
#  'girt',
#  "'elmos",
#  'eenrtu',
#  'eehrt',
#  'dens',
#  'agin',
#  'acenst',
#  'deirst',
#  'demo',
#  'amno',
#  'aeglns',
#  'aefls',
#  'aemr',
#  'aderst',
#  'psu',
#  'eeprst',
#  "'aeprst",
#  'almnor',
#  "'msstu",
#  'fist',
#  'aceorsst',
#  "'inst",
#  'adeln',
#  'eillvy',
#  'aswy',
#  'aaeemnt',
#  'aemrst',
#  'deirr',
#  'eilr',
#  'aeehnrt',
#  'deflow',
#  'elmnos',
#  "'cehirs",
#  'ccorsu',
#  'eemst',
#  'deloot',
#  'aeimnr',
#  'eilrsv',
#  'aersv',
#  "'aeirss",
#  'efinst',
#  'eginst',
#  'aaceinrst',
#  'eeilrsv',
#  'deeimrt',
#  'deilors',
#  ...]

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
longest_list = max(more_than_one.values(), key=len)
longest_list
# Out:
# ['slate', 'tesla', 'tales', 'stael', 'teals', 'stale', 'least', 'steal']

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %%
word_length = 10
def longest_anagram_list(word_length):
  filtered_words = [word for word in word_list if len(word) == word_length]
  anagram_map = all_anagram_lists(filtered_words)
  more_than_one = {k:v for k,v in anagram_map.items() if len(v)>1}
  longest_list = max(more_than_one.values(), key=len)
  return longest_list

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %%
anagram_map = all_anagram_lists(short_word_list)
more_than_one = {k:v for k,v in anagram_map.items() if len(v)>1}
anagram_pairs=[]
for k,v in more_than_one.items():
  for word1 in v:
    for word2 in v:
      if word1 != word2:
        anagram_pairs.append((word1,word2))
anagram_pairs
# Out:
# [('proudest', 'sprouted'),
#  ('sprouted', 'proudest'),
#  ('stop', 'pots'),
#  ('stop', 'tops'),
#  ('pots', 'stop'),
#  ('pots', 'tops'),
#  ('tops', 'stop'),
#  ('tops', 'pots')]

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
